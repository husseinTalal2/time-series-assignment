# %% [markdown]
# # Statsmodels Time Series Excercises
# For this set of exercises we're using data from the Federal Reserve Economic Database (FRED) concerning the Industrial Production Index for Electricity and Gas Utilities from January 1970 to December 1989.
#
# Data source: https://fred.stlouisfed.org/series/IPG2211A2N
#
# <div class="alert alert-danger" style="margin: 10px"><strong>IMPORTANT NOTE!</strong> Make sure you don't run the cells directly above the example output shown, <br>otherwise you will end up writing over the example output!</div>

# %%
# RUN THIS CELL
import pandas as pd
import numpy as np
# %matplotlib inline

# %% [markdown]
# ### Load dataset
# load the dataset, don't forget to set the index column and parse the dates correctly so that pandas can understand it, also set the frequency of the data.

# %%
# CODE HERE
df = pd.read_csv("./data/EnergyProduction.csv", index_col="DATE",parse_dates=True)
df.head()
# Out:
#             EnergyIndex
# DATE
# 1970-01-01      43.0869
# 1970-02-01      42.5577
# 1970-03-01      41.6215
# 1970-04-01      40.1982
# 1970-05-01      39.9321

# %%
## DON'T WRITE HERE
# Out:
#             EnergyIndex
# DATE
# 1970-01-01      43.0869
# 1970-02-01      42.5577
# 1970-03-01      41.6215
# 1970-04-01      40.1982
# 1970-05-01      39.9321

# %% [markdown]
# ### 1. Assign a frequency of 'MS' to the DatetimeIndex.

# %%
# CODE HERE
df.index.freq = "MS"
df.head()
# Out:
#             EnergyIndex
# DATE
# 1970-01-01      43.0869
# 1970-02-01      42.5577
# 1970-03-01      41.6215
# 1970-04-01      40.1982
# 1970-05-01      39.9321

# %%
# DON'T WRITE HERE
# Out:
# DatetimeIndex(['1970-01-01', '1970-02-01', '1970-03-01', '1970-04-01',
#                '1970-05-01', '1970-06-01', '1970-07-01', '1970-08-01',
#                '1970-09-01', '1970-10-01',
#                ...
#                '1989-03-01', '1989-04-01', '1989-05-01', '1989-06-01',
#                '1989-07-01', '1989-08-01', '1989-09-01', '1989-10-01',
#                '1989-11-01', '1989-12-01'],
#               dtype='datetime64[ns]', name='DATE', length=240, freq='MS')

# %% [markdown]
# ### 2. Plot the dataset.

# %%
# CODE HERE
df.plot(figsize=(12,6))
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
# DON'T WRITE HERE

# %% [markdown]
# ### 3. Add a column that shows a 12-month Simple Moving Average (SMA).<br>&nbsp;&nbsp;&nbsp;&nbsp;Plot the result.

# %%
df["SMA12"] = df.rolling(window=12).mean()
df.plot(legend=True, figsize=(12,6))
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
# DON'T WRITE HERE

# %% [markdown]
# ### 4. Add a column that shows an Exponentially Weighted Moving Average (EWMA) with a span of 12 using the statsmodels <tt>SimpleExpSmoothing</tt> function. Plot the result.

# %%
# DON'T FORGET TO PERFORM THE IMPORT!
from statsmodels.tsa.api import SimpleExpSmoothing
df["SES12"] = df["EnergyIndex"].ewm(span=12,adjust=False).mean()

df.plot(legend=True, figsize=(12,6))
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
# DON'T WRITE HERE

# %% [markdown]
# ### 5. Add a column to the DataFrame that shows a Holt-Winters fitted model using Triple Exponential Smoothing with multiplicative models. Plot the result.

# %%
# DON'T FORGET TO PERFORM THE IMPORT!
from statsmodels.tsa.api import ExponentialSmoothing
df['TESmul12'] = ExponentialSmoothing(df['EnergyIndex'],trend='mul',seasonal='mul',seasonal_periods=12).fit().fittedvalues
df.plot(legend=True, figsize=(12,6))
# Out:
# C:\Users\Hussein Talal\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:427: FutureWarning: After 0.13 initialization must be handled at model creation
#   warnings.warn(
# <AxesSubplot:xlabel='DATE'>

# %%
# DON'T WRITE HERE

# %% [markdown]
# ### OPTIONAL: Plot the same  as above, but for only the first two years.

# %%
df.iloc[:24].plot(legend=True, figsize=(12,6))
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
# DON'T WRITE HERE

# %% [markdown]
# ### BONUS QUESTION: There is a visible decline in the Industrial Production Index around 1982-1983.<br>Why do you think this might be?

# %%
df["EnergyIndex"].iloc[144:169].plot(legend=True, figsize=(12,6))
# Out:
# <AxesSubplot:xlabel='DATE'>

# %% [markdown]
# I think this is related https://www.bls.gov/opub/mlr/1984/01/rpt2full.pdf

# %% [markdown]
# ## Great job!
